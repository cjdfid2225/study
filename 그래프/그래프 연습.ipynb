# %%
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc
# %matplotlib inline

# %%
# matplotlib 에서 기본적으로 한글을 지원하지 않으므로, 폰트 변경 코드 필요
# 폰트 변경 코드
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font',family='AppleGothic')
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)
else: print('Unknown System.....')

# %%
import pandas as pd

# 막대그래프
data = {'1학년': 120, 
        '2학년': 99, 
        '3학년': 110, 
        '4학년': 130, 
        '5학년': 86, 
        '6학년': 107}
d = pd.Series(data)
x_ = d.values
y_ = d.index

rects = plt.bar(y_,x_,color='blue',label='number')
plt.legend()
plt.show()

# %%
# 누적막대
data = {'1학년':[120,70,50],
       '2학년':[99,50,49],
       '3학년':[110,50,60],
       '4학년':[130,65,65],
       '5학년':[86,40,46],
       '6학년':[107,52,55]}
d = pd.DataFrame(data, index=['전체인원','여학생 수','남학생 수'])
x1_ = d.loc['전체인원'];x_f = d.loc['여학생 수'];x_m = d.loc['남학생 수']
y_ = d.columns

plt.bar(y_,x_f,color='skyblue',bottom=x_m,label='여학생')
plt.bar(y_,x_m,color='hotpink',label='남학생')
plt.legend()
plt.show()

# %%
# 파이차트
data = {'1학년': 120, 
        '2학년': 99, 
        '3학년': 110, 
        '4학년': 130, 
        '5학년': 86, 
        '6학년': 107}
d = pd.Series(data)
x_ = d.values
y_ = d.index

color = ['burlywood','crimson','yellow','violet','limegreen','aquamarine']
pie1 = plt.pie(x_,labels=y_,colors=color,explode=(0.05,0.05,0.05,0.05,0.05,0.05),autopct="%1.1f%%")
plt.show()

# %%
import numpy as np

data = pd.Series([0,0,5,7,8,9,12,14,22,23])
plt.figure(figsize=(7,6))
boxplot = plt.boxplot([data.values],labels=['num'])
plt.yticks(np.arange(0,30,step=5))
plt.show()

# %%
from scipy import stats

x = np.array([3,30,35,40,55,48,49,51,57,55,53,51,60,67,63,90,100])
df = pd.DataFrame(x,columns=['feature1'])
tresh = 1.5
df[(np.abs(stats.zscore(df))>tresh).all(axis=1)].values.ravel() #outlier 제거
np.percentile(df[(np.abs(stats.zscore(df))<tresh).all(axis=1)].values.ravel(),\
             [0,25,50,75,100],interpolation='nearest') #최소,최대,백분위수 출력
plt.figure(figsize=(7,6))
boxplot = plt.boxplot([x])
plt.yticks(np.arange(0,101,step=5))
plt.show()
